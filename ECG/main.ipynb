# %%
import os
import argparse
import warnings
import sklearn.exceptions
warnings.filterwarnings("ignore", category=sklearn.exceptions.UndefinedMetricWarning)

notebooks = ['configs.ipynb', 'model.ipynb', 'utils.ipynb', 'train.ipynb', 'dataload.ipynb']
for nb in notebooks:
    # %run {nb}

parser = argparse.ArgumentParser()

# ========  Experiments Name ================
parser.add_argument('--save_dir',               default='experiments_logs',         type=str, help='Directory containing all experiments')
parser.add_argument('--experiment_description', default='Exp1',   type=str, help='experiment name')
parser.add_argument('--run_description',        default='run1',     type=str, help='run name')

# ========= Select the DATASET ==============
parser.add_argument('--dataset',                default='incart',           type=str, help='mit, incart')
parser.add_argument('--seed_id',                default='0',             type=str, help='to fix a seed while training')

# ========= Experiment settings ===============
parser.add_argument('--data_path',              default=r'data',           type=str,   help='Path containing dataset')

parser.add_argument('--num_runs',               default=1,                 type=int,   help='Number of consecutive run with different seeds')
parser.add_argument('--device',                 default='cuda:0',            type=str,   help='cpu or cuda')


# args = parser.parse_args()
args, unknown = parser.parse_known_args()

if __name__ == "__main__":
    trainer = trainer(args)
    trainer.train()
# Out:
# =============================================
# Dataset: incart
# =============================================
# Seed: 0
# =============================================
# {'num_epochs': 60, 'batch_size': 128, 'weight_decay': 0.0001, 'learning_rate': 0.001, 'feature_dim': 128}
# /home/qziedu/anaconda3/lib/python3.12/site-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [Epoch : 1/60]
# Total_loss	: 0.1626
# TRAIN: Acc:98.6300 	 F1:96.8594
# VAL  : Acc:98.5886 	 F1:96.7616 (best: 96.7616)
# -------------------------------------
# [Epoch : 2/60]
# Total_loss	: 0.1198
# TRAIN: Acc:98.7115 	 F1:97.0747
# VAL  : Acc:98.6998 	 F1:97.0489 (best: 97.0489)
# -------------------------------------
# [Epoch : 3/60]
# Total_loss	: 0.1007
# TRAIN: Acc:99.0964 	 F1:97.9569
# VAL  : Acc:99.0591 	 F1:97.8730 (best: 97.8730)
# -------------------------------------
# [Epoch : 4/60]
# Total_loss	: 0.0890
# TRAIN: Acc:99.2425 	 F1:98.2603
# VAL  : Acc:99.1047 	 F1:97.9395 (best: 97.9395)
# -------------------------------------
# [Epoch : 5/60]
# Total_loss	: 0.0808
# TRAIN: Acc:99.4046 	 F1:98.6408
# VAL  : Acc:99.2986 	 F1:98.4030 (best: 98.4030)
# -------------------------------------
# [Epoch : 6/60]
# Total_loss	: 0.0748
# TRAIN: Acc:99.3714 	 F1:98.5573
# VAL  : Acc:99.2587 	 F1:98.3015 (best: 98.4030)
# -------------------------------------
# [Epoch : 7/60]
# Total_loss	: 0.0700
# TRAIN: Acc:99.4634 	 F1:98.7805
# VAL  : Acc:99.3642 	 F1:98.5583 (best: 98.5583)
# -------------------------------------
# [Epoch : 8/60]
# Total_loss	: 0.0663
# TRAIN: Acc:99.5108 	 F1:98.8868
# VAL  : Acc:99.3699 	 F1:98.5679 (best: 98.5679)
# -------------------------------------
# [Epoch : 9/60]
# Total_loss	: 0.0632
# TRAIN: Acc:99.4397 	 F1:98.7154
# VAL  : Acc:99.3499 	 F1:98.5106 (best: 98.5679)
# -------------------------------------
# [Epoch : 10/60]
# Total_loss	: 0.0606
# TRAIN: Acc:99.4747 	 F1:98.8030
# VAL  : Acc:99.3242 	 F1:98.4634 (best: 98.5679)
# -------------------------------------
# [Epoch : 11/60]
# Total_loss	: 0.0583
# TRAIN: Acc:99.4321 	 F1:98.7200
# VAL  : Acc:99.2900 	 F1:98.4044 (best: 98.5679)
# -------------------------------------
# [Epoch : 12/60]
# Total_loss	: 0.0562
# TRAIN: Acc:99.4994 	 F1:98.8661
# VAL  : Acc:99.3756 	 F1:98.5883 (best: 98.5883)
# -------------------------------------
# [Epoch : 13/60]
# Total_loss	: 0.0544
# TRAIN: Acc:99.3287 	 F1:98.4608
# VAL  : Acc:99.2416 	 F1:98.2627 (best: 98.5883)
# -------------------------------------
# [Epoch : 14/60]
# Total_loss	: 0.0529
# TRAIN: Acc:99.5335 	 F1:98.9410
# VAL  : Acc:99.3328 	 F1:98.4874 (best: 98.5883)
# -------------------------------------
# [Epoch : 15/60]
# Total_loss	: 0.0515
# TRAIN: Acc:99.5051 	 F1:98.8842
# VAL  : Acc:99.3870 	 F1:98.6210 (best: 98.6210)
# -------------------------------------
# [Epoch : 16/60]
# Total_loss	: 0.0502
# TRAIN: Acc:99.5364 	 F1:98.9507
# VAL  : Acc:99.3642 	 F1:98.5658 (best: 98.6210)
# -------------------------------------
# [Epoch : 17/60]
# Total_loss	: 0.0490
# TRAIN: Acc:99.5658 	 F1:99.0146
# VAL  : Acc:99.4269 	 F1:98.7033 (best: 98.7033)
# -------------------------------------
# [Epoch : 18/60]
# Total_loss	: 0.0480
# TRAIN: Acc:99.5914 	 F1:99.0728
# VAL  : Acc:99.4982 	 F1:98.8632 (best: 98.8632)
# -------------------------------------
# [Epoch : 19/60]
# Total_loss	: 0.0470
# TRAIN: Acc:99.5762 	 F1:99.0366
# VAL  : Acc:99.4297 	 F1:98.7039 (best: 98.8632)
# -------------------------------------
# [Epoch : 20/60]
# Total_loss	: 0.0460
# TRAIN: Acc:99.5364 	 F1:98.9467
# VAL  : Acc:99.3727 	 F1:98.5773 (best: 98.8632)
# -------------------------------------
# [Epoch : 21/60]
# Total_loss	: 0.0452
# TRAIN: Acc:99.5639 	 F1:99.0029
# VAL  : Acc:99.4411 	 F1:98.7211 (best: 98.8632)
# -------------------------------------
# [Epoch : 22/60]
# Total_loss	: 0.0444
# TRAIN: Acc:99.6464 	 F1:99.1974
# VAL  : Acc:99.4754 	 F1:98.8097 (best: 98.8632)
# -------------------------------------
# [Epoch : 23/60]
# Total_loss	: 0.0436
# TRAIN: Acc:99.4454 	 F1:98.7334
# VAL  : Acc:99.2786 	 F1:98.3523 (best: 98.8632)
# -------------------------------------
# [Epoch : 24/60]
# Total_loss	: 0.0429
# TRAIN: Acc:99.6397 	 F1:99.1832
# VAL  : Acc:99.4839 	 F1:98.8321 (best: 98.8632)
# -------------------------------------
# [Epoch : 25/60]
# Total_loss	: 0.0423
# TRAIN: Acc:99.6170 	 F1:99.1250
# VAL  : Acc:99.4526 	 F1:98.7492 (best: 98.8632)
# -------------------------------------
# [Epoch : 26/60]
# Total_loss	: 0.0417
# TRAIN: Acc:99.6094 	 F1:99.1103
# VAL  : Acc:99.4383 	 F1:98.7197 (best: 98.8632)
# -------------------------------------
# [Epoch : 27/60]
# Total_loss	: 0.0412
# TRAIN: Acc:99.6530 	 F1:99.2113
# VAL  : Acc:99.4297 	 F1:98.7057 (best: 98.8632)
# -------------------------------------
# [Epoch : 28/60]
# Total_loss	: 0.0406
# TRAIN: Acc:99.5468 	 F1:98.9624
# VAL  : Acc:99.3727 	 F1:98.5614 (best: 98.8632)
# -------------------------------------
# [Epoch : 29/60]
# Total_loss	: 0.0401
# TRAIN: Acc:99.6985 	 F1:99.3155
# VAL  : Acc:99.5210 	 F1:98.9119 (best: 98.9119)
# -------------------------------------
# [Epoch : 30/60]
# Total_loss	: 0.0395
# TRAIN: Acc:99.6852 	 F1:99.2858
# VAL  : Acc:99.5210 	 F1:98.9144 (best: 98.9144)
# -------------------------------------
# [Epoch : 31/60]
# Total_loss	: 0.0391
# TRAIN: Acc:99.6065 	 F1:99.1031
# VAL  : Acc:99.3813 	 F1:98.5887 (best: 98.9144)
# -------------------------------------
# [Epoch : 32/60]
# Total_loss	: 0.0386
# TRAIN: Acc:99.6710 	 F1:99.2518
# VAL  : Acc:99.5067 	 F1:98.8812 (best: 98.9144)
# -------------------------------------
# [Epoch : 33/60]
# Total_loss	: 0.0382
# TRAIN: Acc:99.5933 	 F1:99.0739
# VAL  : Acc:99.4212 	 F1:98.6823 (best: 98.9144)
# -------------------------------------
# [Epoch : 34/60]
# Total_loss	: 0.0378
# TRAIN: Acc:99.6767 	 F1:99.2663
# VAL  : Acc:99.4982 	 F1:98.8612 (best: 98.9144)
# -------------------------------------
# [Epoch : 35/60]
# Total_loss	: 0.0374
# TRAIN: Acc:99.5658 	 F1:99.0194
# VAL  : Acc:99.4012 	 F1:98.6496 (best: 98.9144)
# -------------------------------------
# [Epoch : 36/60]
# Total_loss	: 0.0371
# TRAIN: Acc:99.7013 	 F1:99.3188
# VAL  : Acc:99.5352 	 F1:98.9384 (best: 98.9384)
# -------------------------------------
# [Epoch : 37/60]
# Total_loss	: 0.0367
# TRAIN: Acc:99.6729 	 F1:99.2596
# VAL  : Acc:99.5039 	 F1:98.8783 (best: 98.9384)
# -------------------------------------
# [Epoch : 38/60]
# Total_loss	: 0.0364
# TRAIN: Acc:99.6691 	 F1:99.2476
# VAL  : Acc:99.5523 	 F1:98.9829 (best: 98.9829)
# -------------------------------------
# [Epoch : 39/60]
# Total_loss	: 0.0360
# TRAIN: Acc:99.6890 	 F1:99.2915
# VAL  : Acc:99.4953 	 F1:98.8486 (best: 98.9829)
# -------------------------------------
# [Epoch : 40/60]
# Total_loss	: 0.0357
# TRAIN: Acc:99.4842 	 F1:98.8179
# VAL  : Acc:99.3499 	 F1:98.5106 (best: 98.9829)
# -------------------------------------
# [Epoch : 41/60]
# Total_loss	: 0.0354
# TRAIN: Acc:99.6435 	 F1:99.1936
# VAL  : Acc:99.4440 	 F1:98.7435 (best: 98.9829)
# -------------------------------------
# [Epoch : 42/60]
# Total_loss	: 0.0351
# TRAIN: Acc:99.6862 	 F1:99.2871
# VAL  : Acc:99.5210 	 F1:98.9119 (best: 98.9829)
# -------------------------------------
# [Epoch : 43/60]
# Total_loss	: 0.0348
# TRAIN: Acc:99.6672 	 F1:99.2406
# VAL  : Acc:99.5295 	 F1:98.9275 (best: 98.9829)
# -------------------------------------
# [Epoch : 44/60]
# Total_loss	: 0.0345
# TRAIN: Acc:99.7099 	 F1:99.3394
# VAL  : Acc:99.5666 	 F1:99.0127 (best: 99.0127)
# -------------------------------------
# [Epoch : 45/60]
# Total_loss	: 0.0343
# TRAIN: Acc:99.5743 	 F1:99.0367
# VAL  : Acc:99.4269 	 F1:98.7028 (best: 99.0127)
# -------------------------------------
# [Epoch : 46/60]
# Total_loss	: 0.0340
# TRAIN: Acc:99.6217 	 F1:99.1460
# VAL  : Acc:99.5039 	 F1:98.8802 (best: 99.0127)
# -------------------------------------
# [Epoch : 47/60]
# Total_loss	: 0.0338
# TRAIN: Acc:99.6976 	 F1:99.3108
# VAL  : Acc:99.5181 	 F1:98.9030 (best: 99.0127)
# -------------------------------------
# [Epoch : 48/60]
# Total_loss	: 0.0335
# TRAIN: Acc:99.7127 	 F1:99.3495
# VAL  : Acc:99.4953 	 F1:98.8603 (best: 99.0127)
# -------------------------------------
# [Epoch : 49/60]
# Total_loss	: 0.0333
# TRAIN: Acc:99.7260 	 F1:99.3770
# VAL  : Acc:99.5181 	 F1:98.9038 (best: 99.0127)
# -------------------------------------
# [Epoch : 50/60]
# Total_loss	: 0.0331
# TRAIN: Acc:99.6397 	 F1:99.1841
# VAL  : Acc:99.4697 	 F1:98.8000 (best: 99.0127)
# -------------------------------------
# [Epoch : 51/60]
# Total_loss	: 0.0328
# TRAIN: Acc:99.7070 	 F1:99.3343
# VAL  : Acc:99.5695 	 F1:99.0219 (best: 99.0219)
# -------------------------------------
# [Epoch : 52/60]
# Total_loss	: 0.0326
# TRAIN: Acc:99.6132 	 F1:99.1274
# VAL  : Acc:99.4240 	 F1:98.7047 (best: 99.0219)
# -------------------------------------
# [Epoch : 53/60]
# Total_loss	: 0.0324
# TRAIN: Acc:99.6748 	 F1:99.2599
# VAL  : Acc:99.4925 	 F1:98.8465 (best: 99.0219)
# -------------------------------------
# [Epoch : 54/60]
# Total_loss	: 0.0322
# TRAIN: Acc:99.7203 	 F1:99.3662
# VAL  : Acc:99.5238 	 F1:98.9231 (best: 99.0219)
# -------------------------------------
# [Epoch : 55/60]
# Total_loss	: 0.0320
# TRAIN: Acc:99.6473 	 F1:99.1946
# VAL  : Acc:99.4668 	 F1:98.7797 (best: 99.0219)
# -------------------------------------
# [Epoch : 56/60]
# Total_loss	: 0.0318
# TRAIN: Acc:99.6938 	 F1:99.3066
# VAL  : Acc:99.5295 	 F1:98.9364 (best: 99.0219)
# -------------------------------------
# [Epoch : 57/60]
# Total_loss	: 0.0316
# TRAIN: Acc:99.5800 	 F1:99.0536
# VAL  : Acc:99.3784 	 F1:98.6037 (best: 99.0219)
# -------------------------------------
# [Epoch : 58/60]
# Total_loss	: 0.0315
# TRAIN: Acc:99.7013 	 F1:99.3229
# VAL  : Acc:99.5153 	 F1:98.9034 (best: 99.0219)
# -------------------------------------
# [Epoch : 59/60]
# Total_loss	: 0.0313
# TRAIN: Acc:99.7307 	 F1:99.3901
# VAL  : Acc:99.5010 	 F1:98.8695 (best: 99.0219)
# -------------------------------------
# [Epoch : 60/60]
# Total_loss	: 0.0311
# TRAIN: Acc:99.6805 	 F1:99.2719
# VAL  : Acc:99.4611 	 F1:98.7732 (best: 99.0219)
# -------------------------------------
# LAST EPOCH PERFORMANCE on validation set...
# Acc:99.4611 	 F1:98.7732
# :::::::::::::
# BEST EPOCH PERFORMANCE on validation set ...
# Acc:99.5695 	 F1:99.0219
#  === Evaluating on TEST set ===
# Acc:99.4684 	 F1:98.7892
